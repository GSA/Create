# %%
#This notebook is to see what happens when I pull

# %%
# %skip
#Let's skip this

# %%
# %sh
# Navigate to the repo (path varies by setup; common legacy path shown)
cd /Workspace/Repos/<your-user-or-org>/<repo-name>
/Workspace/Users/gail.schneider@gsa.gov/Create Tables/Create
# Check status
git status

# Add and commit
git add .
git commit -m "Updated notebooks from Databricks"

# Push (credentials must be configured, e.g., via PAT in remote URL)
git push origin <branch-name>
